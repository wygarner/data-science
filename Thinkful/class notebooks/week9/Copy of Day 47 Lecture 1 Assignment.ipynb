# %% [markdown]
# ## Day 47 Lecture 1 Assignment
#
# In this assignment, we will apply k-means clustering to a dataset containing player-season statistics for NBA players from the past four years.

# %%
# %reload_ext nb_black

# %%
import numpy as np
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# This dataset contains player-season statistics for NBA players from the past four years. Each row in this dataset represents a player's per-game averages for a single season.
#
# This dataset contains the following variables:
#
# - Seas: season ('2019' = 2018-2019 season, '2018' = 2017-2018 season, etc.)
# - Player: player name
# - Pos: position
# - Age: age
# - Tm: team
# - G: games played
# - GS: games started
# - MP: minutes played
# - FG: field goals
# - FGA: field goals attempted
# - FG%: field goal percentage
# - 3P: 3 pointers
# - 3PA: 3 pointers attempted
# - 3P%: 3 point percentage
# - 2P: 2 pointers
# - 2PA: 2 pointers attempted
# - 2P%: 2 point percentage
# - eFG%: effective field goal percentage
# - FT: free throws
# - FTA: free throws attempted
# - FT%: free throw percentage
# - ORB: offensive rebound
# - DRB: defensive rebound
# - TRB: total rebounds
# - AST: assists
# - STL: steals
# - BLK: blocks
# - TOV: turnovers
# - PF: personal fouls
# - PTS: points
#
# Load the dataset.

# %%
# answer goes here
url = "https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Clustering/nba_player_seasons.csv"
nba = pd.read_csv(url)
nba.head()
# Out:
#    Seas        Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  ORB  \
# 0  2019  Álex Abrines  SG   25  OKC  31   2  19.0  1.8   5.1  ...  0.923  0.2
# 1  2019    Quincy Acy  PF   28  PHO  10   0  12.3  0.4   1.8  ...  0.700  0.3
# 2  2019  Jaylen Adams  PG   22  ATL  34   1  12.6  1.1   3.2  ...  0.778  0.3
# 3  2019  Steven Adams   C   25  OKC  80  80  33.4  6.0  10.1  ...  0.500  4.9
# 4  2019   Bam Adebayo   C   21  MIA  82  28  23.3  3.4   5.9  ...  0.735  2.0
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.4  1.5  0.6  0.5  0.2  0.5  1.7   5.3
# 1  2.2  2.5  0.8  0.1  0.4  0.4  2.4   1.7
# 2  1.4  1.8  1.9  0.4  0.1  0.8  1.3   3.2
# 3  4.6  9.5  1.6  1.5  1.0  1.7  2.6  13.9
# 4  5.3  7.3  2.2  0.9  0.8  1.5  2.5   8.9
#
# [5 rows x 30 columns]

# %% [markdown]
# The goal is to cluster these player-seasons to identify potential player "archetypes".
#
# Begin by removing players whose season did not meet one of the following criteria:
# 1. Started at least 20 games
# 2. Averaged at least 10 minutes per game

# %%
# answer goes here
nba = nba[nba["GS"] >= 20]
nba = nba[nba["MP"] >= 10]
nba_og = nba.copy()

# %% [markdown]
# Choose a subset of numeric columns that is interesting to you from an "archetypal" standpoint.
#
# We will choose the following basic statistics: **points, total rebounds, assists, steals, blocks**, and **turnovers**, but you should feel free to choose other reasonable feature sets if you like. Be careful not to include too many dimensions (curse of dimensionality).

# %%
# answer goes here
cols = ["PTS", "TRB", "AST", "STL", "BLK", "TOV"]
nba = nba[cols]
nba.head()
# Out:
#      PTS  TRB  AST  STL  BLK  TOV
# 3   13.9  9.5  1.6  1.5  1.0  1.7
# 4    8.9  7.3  2.2  0.9  0.8  1.5
# 7   21.3  9.2  2.4  0.5  1.3  1.8
# 10  10.9  8.4  1.4  0.5  1.5  1.3
# 12   9.4  7.5  1.3  0.8  0.4  0.9

# %% [markdown]
# Standardize the features in your dataset using scikit-learn's StandardScaler, which will set the mean of each feature to 0 and the variance to 1.

# %%
# answer goes here
scaler = StandardScaler()
nba_scaled = scaler.fit_transform(nba)

nba_scaled = pd.DataFrame(nba_scaled, columns=nba.columns, index=nba.index)
nba_scaled.head()
# Out:
#          PTS       TRB       AST       STL       BLK       TOV
# 3   0.114638  1.612909 -0.617816  1.393220  0.824001  0.023511
# 4  -0.744985  0.768627 -0.330886 -0.050271  0.420162 -0.218831
# 7   1.386880  1.497780 -0.235242 -1.012598  1.429758  0.144681
# 10 -0.401136  1.190768 -0.713459 -1.012598  1.833596 -0.461172
# 12 -0.659023  0.845380 -0.761281 -0.290853 -0.387514 -0.945854

# %% [markdown]
# Run K-means clustering with K = 3 and print out the resulting centroids. When printing the centroids, transform the scaled centroids back into their corresponding unscaled values. What "archetypes" do you see?

# %%
# answer goes here
kmeans = KMeans(n_clusters=5)
kmeans.fit(nba_scaled)

centroids = kmeans.cluster_centers_
centroids_df = pd.DataFrame(scaler.inverse_transform(centroids), columns=nba.columns)
centroids_df
# Out:
#          PTS        TRB       AST       STL       BLK       TOV
# 0  18.730303  10.577273  2.603030  0.972727  1.692424  2.315152
# 1   7.755155   3.478351  1.409794  0.608247  0.356186  0.906701
# 2  19.707639   5.226389  6.286806  1.395833  0.454861  2.878472
# 3  13.446639   4.036975  2.964286  1.035294  0.334034  1.613025
# 4  11.485185   7.238272  1.660494  0.683951  0.926543  1.383333

# %%
nba_og["label"] = kmeans.labels_
pos_label_ct = pd.crosstab(nba_og["label"], nba_og["Pos"])
display(pos_label_ct)
display(pos_label_ct.style.background_gradient(axis=1))

sns.countplot("Pos", hue="label", data=nba_og)
plt.legend(loc="upper right")
plt.show()
# Out:
# Pos     C  PF  PF-C  PF-SF  PG  SF  SF-SG  SG
# label
# 0      53  10     0      0   1   2      0   0
# 1      22  44     1      1  15  48      0  63
# 2       2  11     0      0  83  17      1  30
# 3       1  24     0      1  60  72      1  79
# 4      88  66     0      0   0   7      0   1
# <style  type="text/css" >
#     #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col1 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col5 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col0 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col1 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col2 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col4 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col5 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow2_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow2_col1 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow2_col5 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow2_col6 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow2_col7 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow3_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow3_col1 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow3_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow3_col4 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow3_col5 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow3_col6 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow3_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow4_col1 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow4_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow4_col5 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow4_col7 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }</style><table id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4ef" ><thead>    <tr>        <th class="index_name level0" >Pos</th>        <th class="col_heading level0 col0" >C</th>        <th class="col_heading level0 col1" >PF</th>        <th class="col_heading level0 col2" >PF-C</th>        <th class="col_heading level0 col3" >PF-SF</th>        <th class="col_heading level0 col4" >PG</th>        <th class="col_heading level0 col5" >SF</th>        <th class="col_heading level0 col6" >SF-SG</th>        <th class="col_heading level0 col7" >SG</th>    </tr>    <tr>        <th class="index_name level0" >label</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4eflevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col0" class="data row0 col0" >53</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col1" class="data row0 col1" >10</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col4" class="data row0 col4" >1</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col5" class="data row0 col5" >2</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col6" class="data row0 col6" >0</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow0_col7" class="data row0 col7" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4eflevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col0" class="data row1 col0" >22</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col1" class="data row1 col1" >44</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col2" class="data row1 col2" >1</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_5c9f4a36_8fc1_11ea_bb1a_a683e7ada4efrow1_col4" class="data row1 col4" >15</td>

# %%
sns.violinplot("label", "Age", data=nba_og)
plt.show()

# %%
sns.pairplot(nba_og[["PTS", "TRB", "AST", "STL", "BLK", "TOV", "label"]], hue="label")
plt.show()
