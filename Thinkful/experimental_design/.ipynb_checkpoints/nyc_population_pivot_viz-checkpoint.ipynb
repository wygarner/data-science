# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline


data_url = "https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/nyc-population-tall.csv"
nyc_pop = pd.read_csv(data_url)
nyc_pop.head()
# Out:
#    year        borough  population
# 0  1900      Manhattan     1850093
# 1  1900       Brooklyn     1166582
# 2  1900         Queens      152999
# 3  1900          Bronx      200507
# 4  1900  Staten Island       67021

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-6159b7c9cf96> in <module>
# ----> 1 nyc_pop.columns.upper()
#
# AttributeError: 'Index' object has no attribute 'upper'

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='year',y='population',hue='borough',data=nyc_pop,markers=True)
plt.show()
