# %% [markdown]
# # Extracting Information from Text Data Assignment

# %%
import spacy
import string
import textacy
import itertools
from nltk import pos_tag
from rake_nltk import Rake
from nltk import sent_tokenize
from nltk import word_tokenize
from nltk import tree2conlltags
from gensim.summarization import keywords
from nltk.chunk.regexp import RegexpParser
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
import pandas as pd
from itertools import groupby

# %% [markdown]
# ### Read the CNN Lite plain text file articles into a corpus using the NLTK's PlaintextCorpusReader.

# %%
file_location2 = r'C:\Users\Adam Parente\Documents\Python Scripts\thinkful_assignments\example_text_files\cnn'

DOC_PATTERN = r'.*\.txt'


corpus = PlaintextCorpusReader(file_location2, DOC_PATTERN)

# %% [markdown]
# ### Iterate through the fileids in the corpus, extract the raw text of each document, and store them in a list.

# %%
file_ids = corpus.fileids()
text_list = []
for x in file_ids:
    text = corpus.words(x)
    text_list.append(' '.join(text))
text_df = pd.DataFrame({'id':file_ids,'text':text_list})

# %% [markdown]
# ### Extract the top 5 keywords from every document in the corpus. Print them and compare the differences in keywords among the documents.

# %%
key_word_list = []
for x in text_list:
    key_words = keywords(x, words=5, lemmatize=True).split('\n')
    key_word_list.append(key_words)

# %%
key_word_list
# Out:
# [['pink', 'cnn', 'carey', 'tour', 'reserved'],
#  ['patrick', 'primary', 'cnn', 'news', 'telling'],
#  ['narwhal', 'tail', 'puppy', 'cnn', 'unicorn'],
#  ['states', 'democratic', 'news', 'bloomberg', 'cnn'],
#  ['republican', 'taylor', 'presidents', 'rep', 'ukraine'],
#  ['muslimness', 'people', 'skin', 'white', 'religion'],
#  ['news', 'trump', 'said', 'republican', 'media'],
#  ['jones said', 'brown', 'police', 'roanoke'],
#  ['trump', 'hotels', 'office', 'profit', 'owned'],
#  ['keys', 'grammys', 'award', 'reserved', 'wanna'],
#  ['americans', 'republican', 'trump', 'ukrainians', 'investigate'],
#  ['student', 'said', 'told', 'pence', 'schools'],
#  ['cnn', 'crows', 'disney', 'american', 'old'],
#  ['protester', 'police', 'news', 'chinese', 'kong']]

# %% [markdown]
# ### Extract the top 3 keyphrases from each document, print them, and compare the differences.

# %%
key_phrases_list = []
for x in text_list:
    r = Rake()
    r.extract_keywords_from_text(x)
    key_phrases = r.get_ranked_phrases_with_scores()
    key_phrases_list.append(key_phrases)

# %%
key_phrases_list[5]
# Out:
# [(25.0, '© 2019 cable news network'),
#  (20.77777777777778, 'support various international policies --'),
#  (16.0, 'protesters stormed john f'),
#  (16.0, 'executive order banning entry'),
#  (15.5, 'president donald trump issued'),
#  (15.333333333333334, 'every pearl jam song'),
#  (14.5, 'words would always ring'),
#  (13.833333333333334, 'gently educating people —'),
#  (13.277777777777779, 'wildly misunderstood -- religion'),
#  (13.0, 'people would judge us'),
#  (12.94047619047619, 'american muslim girl editor'),
#  (12.833333333333334, 'even basic american girls'),
#  (12.666666666666666, 'actually pray every day'),
#  (11.44047619047619, 'american muslim girl ."'),
#  (9.166666666666666, 'day trump instituted'),
#  (9.0, 'turner broadcasting system'),
#  (9.0, 'syria ), thousands'),
#  (9.0, 'rarely attend mosque'),
#  (9.0, 'new york city'),
#  (9.0, 'nadine jolie courtney'),
#  (9.0, 'indefinitely halting refugees'),
#  (9.0, 'done anything wrong'),
#  (8.94047619047619, 'american muslim girl'),
#  (8.833333333333334, 'religion silent —'),
#  (8.666666666666666, 'pray multiple times'),
#  (8.5, 'privilege obviously afforded'),
#  (8.5, 'allahu akbar !"'),
#  (8.333333333333334, 'never broken anything'),
#  (8.333333333333334, 'another time .)'),
#  (8.11111111111111, 'first time --'),
#  (8.0, 'years spent keeping'),
#  (8.0, 'officially began writing'),
#  (8.0, 'novel debunks myths'),
#  (8.0, 'home visiting family'),
#  (8.0, 'full cnn experience'),
#  (7.857142857142858, 'muslim sisters outside'),
#  (7.833333333333334, 'started publicly identifying'),
#  (7.777777777777778, 'circassian heritage --'),
#  (7.777777777777778, 'background -- yes'),
#  (7.666666666666668, 'almost never feel'),
#  (7.533333333333334, 'american muslims like'),
#  (7.5, 'life fought back'),
#  (7.5, 'friend sheepishly told'),
#  (7.333333333333334, 'world — find'),
#  (7.2, 'incredulous comments like'),
#  (6.25, 'basic girl'),
#  (5.833333333333334, 'american !"'),
#  (5.333333333333334, 'every nationality'),
#  (5.277777777777778, 'people --'),
#  (4.857142857142858, 'muslim sisters'),
#  (4.777777777777778, 'beautiful --'),
#  (4.5, 'wanted people'),
#  (4.5, 'publicly claiming'),
#  (4.5, 'people staring'),
#  (4.5, 'largest religion'),
#  (4.5, 'get told'),
#  (4.357142857142858, 'seven muslim'),
#  (4.357142857142858, 'raced muslim'),
#  (4.357142857142858, 'muslim cousins'),
#  (4.357142857142858, 'muslim community'),
#  (4.357142857142858, 'muslim ban'),
#  (4.357142857142858, 'muslim ..."'),
#  (4.357142857142858, 'good muslim'),
#  (4.333333333333334, 'started writing'),
#  (4.333333333333334, 'started enthusiastically'),
#  (4.333333333333334, 'feel honored'),
#  (4.333333333333334, 'feel comfortable'),
#  (4.277777777777778, 'book --'),
#  (4.2, 'lot like'),
#  (4.166666666666667, 'white privilege'),
#  (4.107142857142858, 'one muslim'),
#  (4.0, 'word document'),
#  (4.0, 'wonderfully overwhelming'),
#  (4.0, 'watershed moment'),
#  (4.0, 'views expressed'),
#  (4.0, 'typically dread'),
#  (4.0, 'two worlds'),
#  (4.0, 'two sides'),
#  (4.0, 'travel ban'),
#  (4.0, 'somebody yell'),
#  (4.0, 'skin color'),
#  (4.0, 'rights reserved'),
#  (4.0, 'personal story'),
#  (4.0, 'parking lots'),
#  (4.0, 'pale skin'),
#  (4.0, 'oprah magazine'),
#  (4.0, 'muslimness "...'),
#  (4.0, 'middle eastern'),
#  (4.0, 'make comments'),
#  (4.0, 'majority countries'),
#  (4.0, 'kennedy airport'),
#  (4.0, 'jaws dropping'),
#  (4.0, 'january 27th'),
#  (4.0, 'includes muslims'),
#  (4.0, 'grocery store'),
#  (4.0, 'go back'),
#  (4.0, 'friend shrugged'),
#  (4.0, 'formed bonds'),
#  (4.0, 'feeling caught'),
#  (4.0, 'fair skin'),
#  (4.0, 'events unfolded'),
#  (4.0, 'especially nervous'),
#  (4.0, 'episcopalian nun'),
#  (4.0, 'enjoyed many'),
#  (4.0, 'endless questions'),
#  (4.0, 'doubly profound'),
#  (4.0, 'desperately wants'),
#  (4.0, 'completely unaware'),
#  (4.0, 'casually chat'),
#  (4.0, 'blonde hair'),
#  (4.0, 'best friend'),
#  (4.0, 'bandwidth usage'),
#  (4.0, 'asian ancestry'),
#  (4.0, 'architectural digest'),
#  (4.0, 'airports around'),
#  (4.0, '10 years'),
#  (3.75, 'pervasive one'),
#  (3.75, 'one way'),
#  (3.7, 'like ...'),
#  (3.666666666666667, 'young white'),
#  (3.666666666666667, 'western eyes'),
#  (3.666666666666667, 'mother found'),
#  (3.666666666666667, 'green eyes'),
#  (3.666666666666667, 'born mother'),
#  (3.5, 'stopped hiding'),
#  (3.5, 'right ?"'),
#  (3.5, 'passing 16'),
#  (3.5, 'longer able'),
#  (3.5, 'lifestyle disqualified'),
#  (3.5, 'good enough'),
#  (3.5, 'elementary school'),
#  (3.5, 'eat bacon'),
#  (3.5, 'different story'),
#  (3.5, 'americans looked'),
#  (3.0, 'wear hijab'),
#  (3.0, 'support'),
#  (2.7777777777777777, '--'),
#  (2.6666666666666665, 'pray'),
#  (2.6666666666666665, 'day'),
#  (2.5, 'us'),
#  (2.5, 'religion'),
#  (2.5, 'people'),
#  (2.5, 'even'),
#  (2.5, 'always'),
#  (2.5, '."'),
#  (2.357142857142857, 'muslim'),
#  (2.3333333333333335, 'time'),
#  (2.3333333333333335, 'never'),
#  (2.2, 'like'),
#  (2.0, 'yes'),
#  (2.0, 'years'),
#  (2.0, 'writing'),
#  (2.0, 'world'),
#  (2.0, 'novel'),
#  (2.0, 'muslims'),
#  (2.0, 'life'),
#  (2.0, 'heritage'),
#  (2.0, 'friend'),
#  (2.0, 'find'),
#  (2.0, 'family'),
#  (2.0, 'comments'),
#  (2.0, 'cnn'),
#  (1.75, 'one'),
#  (1.6666666666666667, 'white'),
#  (1.6666666666666667, 'mother'),
#  (1.6666666666666667, 'eyes'),
#  (1.5, 'wear'),
#  (1.5, 'school'),
#  (1.5, 'passing'),
#  (1.5, 'longer'),
#  (1.5, 'lifestyle'),
#  (1.5, 'hijab'),
#  (1.5, 'hiding'),
#  (1.5, 'go'),
#  (1.5, 'enough'),
#  (1.5, 'eat'),
#  (1.5, 'different'),
#  (1.5, 'book'),
#  (1.5, 'americans'),
#  (1.5, '?"'),
#  (1.5, '...'),
#  (1.0, 'year'),
#  (1.0, 'worry'),
#  (1.0, 'working'),
#  (1.0, 'work'),
#  (1.0, 'whether'),
#  (1.0, 'wet'),
#  (1.0, 'water'),
#  (1.0, 'watched'),
#  (1.0, 'walks'),
#  (1.0, 'voice'),
#  (1.0, 'virtue'),
#  (1.0, 'unlike'),
#  (1.0, 'unable'),
#  (1.0, 'trying'),
#  (1.0, 'trust'),
#  (1.0, 'treat'),
#  (1.0, 'trap'),
#  (1.0, 'town'),
#  (1.0, 'title'),
#  (1.0, 'things'),
#  (1.0, 'thing'),
#  (1.0, 'thick'),
#  (1.0, 'tension'),
#  (1.0, 'television'),
#  (1.0, 'subject'),
#  (1.0, 'struggles'),
#  (1.0, 'stomach'),
#  (1.0, 'stemming'),
#  (1.0, 'stare'),
#  (1.0, 'soon'),
#  (1.0, 'solidarity'),
#  (1.0, 'sky'),
#  (1.0, 'side'),
#  (1.0, 'seen'),
#  (1.0, 'second'),
#  (1.0, 'regularly'),
#  (1.0, 'realized'),
#  (1.0, 'read'),
#  (1.0, 'reaction'),
#  (1.0, 'raised'),
#  (1.0, 'quizzically'),
#  (1.0, 'provide'),
#  (1.0, 'proud'),
#  (1.0, 'produced'),
#  (1.0, 'proclaiming'),
#  (1.0, 'practice'),
#  (1.0, 'opinion'),
#  (1.0, 'opened'),
#  (1.0, 'ones'),
#  (1.0, 'old'),
#  (1.0, 'okay'),
#  (1.0, 'note'),
#  (1.0, 'next'),
#  (1.0, 'much'),
#  (1.0, 'monolith'),
#  (1.0, 'mom'),
#  (1.0, 'mixed'),
#  (1.0, 'microaggressions'),
#  (1.0, 'lyrics'),
#  (1.0, 'luckily'),
#  (1.0, 'low'),
#  (1.0, 'love'),
#  (1.0, 'look'),
#  (1.0, 'lived'),
#  (1.0, 'listen'),
#  (1.0, 'law'),
#  (1.0, 'lack'),
#  (1.0, 'koosa'),
#  (1.0, 'know'),
#  (1.0, 'justify'),
#  (1.0, 'islamophobia'),
#  (1.0, 'islam'),
#  (1.0, 'ironically'),
#  (1.0, 'internalized'),
#  (1.0, 'instead'),
#  (1.0, 'inc'),
#  (1.0, 'important'),
#  (1.0, 'impolite'),
#  (1.0, 'identity'),
#  (1.0, 'idea'),
#  (1.0, 'house'),
#  (1.0, 'heartening'),
#  (1.0, 'happened'),
#  (1.0, 'hallway'),
#  (1.0, 'grown'),
#  (1.0, 'friends'),
#  (1.0, 'forget'),
#  (1.0, 'fit'),
#  (1.0, 'figure'),
#  (1.0, 'father'),
#  (1.0, 'falling'),
#  (1.0, 'facts'),
#  (1.0, 'fact'),
#  (1.0, 'exploring'),
#  (1.0, 'explore'),
#  (1.0, 'experienced'),
#  (1.0, 'exactly'),
#  (1.0, 'ethnicity'),
#  (1.0, 'erasure'),
#  (1.0, 'empowered'),
#  (1.0, 'elsewhere'),
#  (1.0, 'ears'),
#  (1.0, 'drink'),
#  (1.0, 'door'),
#  (1.0, 'differently'),
#  (1.0, 'despite'),
#  (1.0, 'danger'),
#  (1.0, 'course'),
#  (1.0, 'country'),
#  (1.0, 'countless'),
#  (1.0, 'computer'),
#  (1.0, 'complex'),
#  (1.0, 'come'),
#  (1.0, 'citizens'),
#  (1.0, 'choose'),
#  (1.0, 'catholic'),
#  (1.0, 'came'),
#  (1.0, 'cabernet'),
#  (1.0, 'built'),
#  (1.0, 'bottle'),
#  (1.0, 'blue'),
#  (1.0, 'believing'),
#  (1.0, 'believe'),
#  (1.0, 'became'),
#  (1.0, 'author'),
#  (1.0, 'aunts'),
#  (1.0, 'asking'),
#  (1.0, 'arabic'),
#  (1.0, 'appeared'),
#  (1.0, 'appearance'),
#  (1.0, 'anybody'),
#  (1.0, 'answer'),
#  (1.0, 'angeleno'),
#  (1.0, 'amto'),
#  (1.0, 'among'),
#  (1.0, 'afraid'),
#  (1.0, 'adore'),
#  (1.0, 'accepted'),
#  (1.0, '2017')]

# %% [markdown]
# ### Identify and extract the named entities in each document, filtering out the numeric types. Print them and compare the differences between documents.

# %%
nlp = spacy.load('en_core_web_sm')
entity_list = []
for x in text_list:
    spacy_doc = nlp(x)
    entities = [[entity.text,entity.label_] for entity in spacy_doc.ents]
    entity_list.append(entities)

# %%
entity_list[0]
# Out:
# [['CNN', 'ORG'],
#  ['2020', 'DATE'],
#  ['Entertainment Tonight', 'WORK_OF_ART'],
#  ['the Country Music Association Awards', 'ORG'],
#  ['Carey Hart', 'PERSON'],
#  ['8', 'DATE'],
#  ['Jameson', 'ORG'],
#  ['2', 'CARDINAL'],
#  ['Love Me Anyway', 'WORK_OF_ART'],
#  ['Chris Stapleton', 'PERSON'],
#  ['two and a half years', 'DATE'],
#  ['Willow', 'PERSON'],
#  ['Jameson', 'PERSON'],
#  ['the year', 'DATE'],
#  ['14 years', 'DATE'],
#  ['January', 'DATE'],
#  ['Carey', 'PERSON'],
#  ['Hart', 'PERSON'],
#  ['Billboard', 'PERSON'],
#  ['10th', 'ORDINAL'],
#  ['more than $ 397 million', 'MONEY'],
#  ['Cable News Network', 'ORG'],
#  ['Turner Broadcasting System , Inc', 'ORG'],
#  ['CNN', 'ORG'],
#  ['CNN', 'ORG']]

# %% [markdown]
# ### Use NLTK's RegexpParser to extract all instances of two or more consecutive nouns (of any tense).

# %%
grammar = r'NP: {<NN><NN>}'
def extract_phrases(doc, grammar):
    chunker = RegexpParser(grammar)
    results = []
    for sent in sent_tokenize(doc):
        tokenized = word_tokenize(sent)
        tagged = pos_tag(tokenized)
        cleaned = [tag for tag in tagged if not tag[1] in string.punctuation]
        
        chunks = tree2conlltags(chunker.parse(cleaned))
        
        phrases = [''.join(word for word, pos, chunk in group)
                      for key, group in groupby(chunks, lambda term: term[-1] != 'O') if key]
        
        results += phrases
        results = list(set(results))
    return results

# %%
GRAMMAR = r'NP: {<NN><NN>}'
nouns_list = []
for x in text_list:
    nouns_list.append(extract_phrases(x,GRAMMAR))
# Out:
# Warning: parsing empty text
# Warning: parsing empty text

# %% [markdown]
# ### For every document in the corpus, iterate over every sentence, extract any SVO triples, print them, and compare.

# %%
svo_list = []
for x in text_list:
    results = []
    spacy_doc = nlp(x)
    for sent in spacy_doc.sents:
        svo = textacy.extract.subject_verb_object_triples(sent)
        results += svo
    results = list(set(results))
    svo_list.append(results)

# %%
svo_list
# Out:
# [[(s, going, to start),
#   (he, follows, me),
#   (she, will celebrate, years),
#   (she, will be taking, step),
#   (it, s, turn),
#   (star, praised, husband)],
#  [(he, regrets, not moving),
#   (he, seeks, nomination),
#   (I, never taken, job),
#   (Patrick, had upped, involvement),
#   (Mayor Michael Bloomberg, stepped, to tease),
#   (He, cited, it),
#   (Patrick, has missed, to appear),
#   (Democrats, have cast, interests),
#   (he, ruled, bid),
#   (he, would be entering, race),
#   (he, could make, minute entry),
#   (Deval Patrick, told, allies),
#   (Deval Patrick, tells, allies),
#   (Patrick, weighing, contest),
#   (source, tells, CNN),
#   (Patrick, had built, team),
#   (Patrick, entered, sector),
#   (that, became, liability),
#   (Patrick, told, WBUR),
#   (Patrick, told, friends),
#   (Patrick, defended, work),
#   (he, wanted, to put),
#   (he, was going, to jump),
#   (he, has made, decision),
#   (Patrick, has missed, deadline),
#   (he, planned, bid),
#   (ve, never taken, job),
#   (Deval Patrick, told, friends),
#   (ve, left, conscience)],
#  [(it, doesn, t wag),
#   (they, want, to monitor),
#   (He, seems, healthy),
#   (spokesperson, told, CNN),
#   (face tail, does not bother, Narwhal),
#   (doesn, cause, pain),
#   (he, got, meds),
#   (what, appears, be),
#   (which, took, him),
#   (doesn, cause, him),
#   (who, has been named, Smurf),
#   (organization, received, adoption applications),
#   (There, s, puppy),
#   (organization, received, for),
#   (He, seems, other),
#   (spokesperson, told, CNN),
#   (they, are seeing, dogs),
#   (there, s, reason),
#   (that, resembles, tusk),
#   (tail, catapulted, him),
#   (it, doesn, t),
#   (Vets, took, ray scans),
#   (which, showed, t),
#   (t, stopped, fans)],
#  [(Patrick, join, field),
#   (she, left, ajar),
#   (d, like, do),
#   (none, could claim, runner status),
#   (which, has prompted, much),
#   (Mayor Michael Bloomberg, made, run),
#   (University poll, showed, Bend),
#   (I, tell, you),
#   (they, miss, chance),
#   (I, tell, m),
#   (public, can make, decision),
#   (we, re going, do),
#   (Biden, held, lead),
#   (Patrick, join, underscores),
#   (he, entered, race),
#   (he, decide, to run),
#   (Hillary Clinton, should run, steal),
#   (admirers, have tried, to coax),
#   (filing deadlines, appear, to have forced),
#   (you, want, to know),
#   (both, have excited, generation),
#   (Clinton, told, BBC radio),
#   (ve, got, to talk),
#   (I, would fix, it),
#   (Bloomberg, told, gaggle),
#   (I, tell, to think),
#   (s team, filed, paperwork),
#   (There, s, lack),
#   (t, tempt, me),
#   (Bloomberg, join, field),
#   (Patrick, missed, deadlines),
#   (University poll, showed, Indiana),
#   (Bloomberg, plans, to skip),
#   (she, ruled, run),
#   (Deval Patrick, weighed, entry),
#   (s, running, campaign),
#   (I, got, do),
#   (Bloomberg, told, reporters),
#   (ve, got, daughters),
#   (she, left, door),
#   (who, could face, disadvantage),
#   (ve, got, grandkids),
#   (We, don, work),
#   (party, has not settled, debate),
#   (Bloomberg, join, underscores),
#   (heavyweights, have dangled, possibility),
#   (ve, known, him),
#   (We, don, t),
#   (polls, demonstrate, lack),
#   (adviser Howard Wolfson, told, CNN),
#   (Clinton, told, Radio)],
#  [(Ukraine, making, statement),
#   (He, derided, impeachment sham),
#   (He, called, proceedings),
#   (He, called, Chamber),
#   (it, tends, have),
#   (we, become, monarchy),
#   (Mark Meadows, told, Fox),
#   (that, balances, powers),
#   (expert Fiona Hill, said, same),
#   (He, called, finale),
#   (Taylor, laid, timeline),
#   (Republicans, had put, signs),
#   (He, called, hearings),
#   (You, re, star witness),
#   (It, s, thing),
#   (Jordan, hit, line),
#   (Jim Jordan, showcases, Republicans),
#   (He, described, door testimony),
#   (Nunes, pushed, Ukraine conspiracy theory),
#   (Russia, annexed, Crimea),
#   (ve, seen, church prayer chains),
#   (that, affirms, view),
#   (Sondland, called, Trump),
#   (I, could tell, did),
#   (Schiff, tried, to ground),
#   (It, seems, unlikely),
#   (House Intelligence Committee, opened, impeachment hearings),
#   (answer, will affect, future),
#   (Congress, had begun, to ask),
#   (President Donald Trump, abused, office),
#   (Nunes, detailed, conspiracy theory),
#   (adviser Tom Bossert, summed, it),
#   (He, dismissed, investigation),
#   (he, mentioned, Founders),
#   (he, began, speaking),
#   (Taylor aide, asked, Sondland),
#   (he, made, clear),
#   (It, s, thing),
#   (Jordan, asked, Taylor),
#   (Taylor, recounted, episode),
#   (Trump, cares, more),
#   (they, added, him),
#   (Kent, sought, to emphasize),
#   (country, announced, investigation),
#   (President, defend, Constitution),
#   (whistleblower, was known, have),
#   (he, hears, it),
#   (There, s, effort),
#   (Devin Nunes, turns, it),
#   (impact, expressed, concerns),
#   (I, monitored, stakes),
#   (appeal, will sway, people),
#   (Partisans, will take, side),
#   (Ukraine, played, role),
#   (allies, abused, office),
#   (. Devin Nunes, sought, to go),
#   (I, doubt, it),
#   (President, brought, conspiracy theory)],
#  [(they, re trying, to figure),
#   (I, eat, bacon),
#   (People, will treat, you),
#   (It, s, day),
#   (that, includes, ethnicity),
#   (somebody, yell, Allahu akbar),
#   (that, includes, lifestyle),
#   (that, includes, skin color),
#   (airports, proclaiming, solidarity),
#   (Trump, instituted, travel ban),
#   (It, s not, comments),
#   (it, s, day),
#   (t, get told, go),
#   (That, s, story),
#   (they, can trust, me),
#   (that, includes, background),
#   (thousands, stormed, F),
#   (t, wear, hijab),
#   (It, s, day),
#   (I, began, writing),
#   (President Donald Trump, issued, order),
#   (It, s, same),
#   (I, started, identifying),
#   (friend, told, me),
#   (that, includes, Muslims),
#   (I, enjoyed, bottle),
#   (who, is exploring, family),
#   (I, choose, to eat),
#   (Trump, instituted, Americans),
#   (ve, enjoyed, bottle),
#   (who, wants, to be accepted),
#   (people, would judge, us),
#   (I, adore, religion),
#   (lifestyle, disqualified, me),
#   (I, became, Editor),
#   (I, choose, not to wear),
#   (they, find, Muslim),
#   (they, know, you),
#   (Years, has produced, tension),
#   (t, done, anything),
#   (I, stopped, hiding),
#   (I, know, lyrics),
#   (I, dread, reaction),
#   (I, support, policies),
#   (I, opened, word document),
#   (mom, didn, t),
#   (I, formed, bonds),
#   (that, had built, life),
#   (Kennedy airport, proclaiming, solidarity),
#   (I, visiting, family)],
#  [(graphic, alleged, MELTDOWN),
#   (Kent, shed, light),
#   (Grisham, called, it),
#   (time stars, are telling, Trump),
#   (banners, summed, s),
#   (process, will hurt, Dems),
#   (defense team, pushed, outlandish conspiracy theory),
#   (inquiry, needs, to stop),
#   (Trish Regan, ran, segment),
#   (I, know, flipping),
#   (Carlson, mocked, news outlets),
#   (Mark Levin, called, Schiff),
#   (NEW EVIDENCE TIES, TRUMP, DIRECTLY),
#   (media, went, bonkers),
#   (others, made, jokes),
#   (I, would sum, everything),
#   (it, did not prove, point),
#   (you, didn, t),
#   (Carlson, seemed, reluctant),
#   (It, didn, t end),
#   (Mark Levin, called, boob),
#   (GOP lawmaker, told, Ingraham),
#   (., say, insanity),
#   (Grisham, called, joke),
#   (that, generated, instances),
#   (Dobbs segment, is sparking, outrage),
#   (There, s, nothing),
#   (Ingraham, welcomed, correspondent),
#   (Which, brings, me),
#   (who, told, him),
#   (hearsay Laura Ingraham, criticized, Democrats),
#   (IMPEACHMENT STUNT, WILL HAUNT, DEMS),
#   (Carlson, wrapped, hour),
#   (that, generated, focus),
#   (you, were watching, hearing),
#   (lawmakers, scrambling, to defend),
#   (who, are resisting, s),
#   (There, s, reason),
#   (defenders, dismissed, hearings),
#   (who, are resisting, policies),
#   (aide, told, Post),
#   (I, decided, to mute),
#   (I, wanted, to know),
#   (president, loved, watching),
#   (he, had been working, phones),
#   (he, accused, witnesses),
#   (I, decided, to write),
#   (Taylor, shed, light)],
#  [(Authorities, received, call),
#   (family, bring, him),
#   (He, is considered, dangerous),
#   (we, can make, arrangements),
#   (Brown, was believed, be),
#   (they, found, Brown),
#   (Brown, deserted, post),
#   (Brown, was driving, Car),
#   (Jones, asked, avoid),
#   (Jones, asked, travel),
#   (Jones, said, to know),
#   (Jones, said, d),
#   (Anyone, should use, call),
#   (Anyone, should use, caution),
#   (he, needs, to contact),
#   (caller, told, investigators),
#   (Jones, described, Brown),
#   (he, can turn, himself),
#   (girlfriend, called, police),
#   (Brown, was believed, to be driving),
#   (Brown, is believed, to be operating),
#   (manhunt, led, police),
#   (We, continue, to urge),
#   (He, switched, vehicles),
#   (who, sees, him),
#   (US Marshals Service, is offering, reward),
#   (police, wanted, anyone),
#   (Office, warned, public),
#   (We, are receiving, intelligence),
#   (what, brought, him)],
#  [(Trump property, has harmed, businesses),
#   (we, have received, interest),
#   (statement, did not list, profit figures),
#   (Trump Organization, won, contract),
#   (t, making, profit),
#   (President, has reported, earning),
#   (company, has hired, estate firm),
#   (we, opened, doors),
#   (agency, ignored, Constitution),
#   (I, will be following, marketing attempt),
#   (Trump Organization, is considering, selling),
#   (President, is violating, Clauses),
#   (Street Journal, reported, sale),
#   (Donald Trump, is profiting, role),
#   (court, revived, lawsuit),
#   (he, transferred, assets),
#   (that, benefits, Trump family),
#   (Trump property, has harmed, Washington hotels),
#   (House Transportation Committee, issued, subpoena),
#   (Trump, took, office)],
#  [(I, going, to bring),
#   (return, puts, her),
#   (it, feels, be),
#   (Keys, told, Billboard),
#   (I, feel, love),
#   (it, confirmed, healing),
#   (ya, gon, na top),
#   (it, confirmed, power),
#   (show, will take, take),
#   (she, became, female),
#   (Alicia Keys, is hosting, Awards),
#   (Alicia Keys, discussing, hosting),
#   (I, felt, it)],
#  [(It, causing, death),
#   (it, helps, case),
#   (which, haunted, half),
#   (He, brushed, assortment),
#   (Trump, distrusts, to convey),
#   (They, posed, sabotage),
#   (delay, meant, death),
#   (Republicans, favor, enforcement),
#   (abuse charge, provides, impeachment theory),
#   (Hunter Biden, being paid, 000),
#   (case, began, to fade),
#   (Ukraine allegations, fail, to resonate),
#   (none, wanted, president),
#   (Courts, prohibit, witness speculation),
#   (actions, may violate, s requirement),
#   (President, abused, power),
#   (Schiff, proceeded, to swear),
#   (Steele Dossier, raised, head),
#   (delay, could telegraph, lack),
#   (Prosecutors, like, to start),
#   (we, will be hearing, more),
#   (fathers, fought, War),
#   (Schiff, followed, rule),
#   (They, posed, questions),
#   (Prosecutors, like, finish),
#   (Republicans, muddied, water),
#   (It, causing, allies),
#   (courtroom, would overrule, questions),
#   (he, didn, t),
#   (Harvard Law grad, executed, part),
#   (prosecutor, executed, part),
#   (they, knew, nothing),
#   (he, was beginning, investigations),
#   (Kent, started, to look),
#   (Having, permitted, to pontificate),
#   (Schiff, accomplished, task),
#   (Richard Nixon, throwing, dollars),
#   (Taylor, revealed, that),
#   (questions, were designed, to remind),
#   (Having, permitted, Republicans),
#   (Taylor, started, to look),
#   (Taylor, explained, backdoor channel),
#   (questions, require, evidence)],
#  [(President, has directed, enforcement agencies),
#   (President Mike Pence, gave, to),
#   (Investigators, will check, rumors),
#   (I, hate, have),
#   (Officials, shepherded, students),
#   (School officials, are sending, students),
#   (President Donald Trump, will work, to end),
#   (School officials, are sending, to),
#   (President Mike Pence, gave, condolences),
#   (we, re going, figure),
#   (Pence, called, it),
#   (he, was leaving, house),
#   (Emergency workers, took, people),
#   (suspect, may have posted, threats),
#   (obtained, shows, suspect),
#   (students, fled, building),
#   (it, s, reality),
#   (gunman, shot, himself),
#   (I, wanted, to make),
#   (sheriff, told, Cooper),
#   (daughter, attends, Saugus),
#   (s neighbor, told, him),
#   (that, affects, us),
#   (she, heard, shot),
#   (we, re going, to move),
#   (cops, say, Angeles),
#   (enforcement sources, told, CNN),
#   (Larry Everhart, told, KCBS),
#   (Students, are trained, to take),
#   (parents, should meet, them),
#   (gunman, shot, classmates),
#   (others, took, cover),
#   (groups, walked, file),
#   (we, re going, have),
#   (I, got, them),
#   (We, were texting, friends),
#   (It, scared, us),
#   (student, told, KTLA),
#   (student, told, KCBS),
#   (we, end, evil),
#   (. Kent Wegener, told, reporters),
#   (granddaughter, threw, arms),
#   (parents, were told, to meet),
#   (He, used, bullet),
#   (Pence, called, day)],
#  [(that, feature, prejudices),
#   (Disney, warns, CNN),
#   (He, omitted, scene),
#   (cartoons, do not represent, society),
#   (They, may depict, some),
#   (It, may contain, depictions),
#   (., used, this),
#   (Disney, warns, viewers),
#   (characters, put, circus tents),
#   (that, feature, content),
#   (movies, outdated, depictions),
#   (Director Tim Burton, chose, to not include),
#   (Dumbo, featured, character)],
#  [(protesters, seek, to breach),
#   (level, has reached, heights),
#   (police, have appeared, reticent),
#   (hundreds, firing, canisters),
#   (protests, have taken, turn),
#   (We, warn, protesters),
#   (you, can make, call),
#   (Adam Ni, told, CNN),
#   (It, echoed, editorial),
#   (protesters, to cross, it),
#   (Student protesters, fortify, campus occupations),
#   (schools, have suspended, classes),
#   (thousands, prepared, to face),
#   (We, have had, persuasion),
#   (students, have been asked, to leave),
#   (MTR, continued, to suspend),
#   (protesters, barricaded, themselves),
#   (We, have had, warnings),
#   (what, is believed, be),
#   (they, had evacuated, students),
#   (government supporters, hurling, bricks),
#   (television channel, issued, editorial),
#   (he, began, clearing),
#   (state media, warning, protesters),
#   (protesters, hurling, bricks),
#   (police, have appeared, to return),
#   (who, are coerced, be),
#   (police, fired, gas),
#   (We, have had, talking),
#   (country, will never accept, situation),
#   (government, unveiled, range),
#   (escalation, raised, questions),
#   (you, are going, have),
#   (them, continued, to pour)]]
