# %% [markdown]
# ## Day 50 Lecture 2 Assignment
#
# In this assignment, we will apply various methods of internal evaluation to the results of K-Means clustering on a dataset containing the results of a survey on financial wellbeing.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans, estimate_bandwidth
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist

# %% [markdown]
# This dataset contains the results of a survey on a financial wellbeing conducted by the US Consumer Finance Protection Bureau that were published in October 2017. This dataset has a large number of columns, most of which correspond to specific questions on the survey. These codebook for translating the column names to questions can be found here:
#
# https://s3.amazonaws.com/files.consumerfinance.gov/f/documents/cfpb_nfwbs-puf-codebook.pdf
#
# Load the dataset.

# %%
data = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Clustering/financial_wellbeing.csv')
data
# Out:
#       PUF_ID  sample  fpl  SWB_1  SWB_2  SWB_3  FWBscore  FWB1_1  FWB1_2  \
# 0      10350       2    3      5      5      6        55       3       3
# 1       7740       1    3      6      6      6        51       2       2
# 2      13699       1    3      4      3      4        49       3       3
# 3       7267       1    3      6      6      6        49       3       3
# 4       7375       1    3      4      4      4        49       3       3
# ...      ...     ...  ...    ...    ...    ...       ...     ...     ...
# 6389   11220       3    3      6      7      7        61       3       3
# 6390   13118       3    2      7      7      7        59       3       4
# 6391    8709       1    3      5      6      6        59       3       4
# 6392    8515       1    3      5      5      5        46       2       2
# 6393    8516       3    2      4      6      4        49       3       3
#
#       FWB1_3  ...  PPMSACAT  PPREG4  PPREG9  PPT01  PPT25  PPT612  PPT1317  \
# 0          3  ...         1       4       8      0      0       0        0
# 1          3  ...         1       2       3      0      0       0        0
# 2          3  ...         1       4       9      0      0       0        1
# 3          3  ...         1       3       7      0      0       0        0
# 4          3  ...         1       2       4      0      0       1        0
# ...      ...  ...       ...     ...     ...    ...    ...     ...      ...
# 6389       1  ...         1       2       3      0      0       0        1
# 6390       2  ...         1       3       6      0      0       0        0
# 6391       3  ...         1       1       2      0      0       0        0
# 6392       3  ...         1       4       9      0      0       0        0
# 6393       3  ...         0       3       5      0      0       1        0
#
#       PPT18OV  PCTLT200FPL   finalwt
# 0           1            0  0.367292
# 1           2            0  1.327561
# 2           2            1  0.835156
# 3           1            0  1.410871
# 4           4            1  4.260668
# ...       ...          ...       ...
# 6389        2           -5  0.522504
# 6390        3           -5  1.015219
# 6391        2            0  1.136270
# 6392        2            0  1.224941
# 6393        2           -5  0.626489
#
# [6394 rows x 217 columns]

# %% [markdown]
# As we did in the previous assignment, we will only use the score columns. Filter the columns of the dataset to only include these columns.

# %%
score_cols = [i for i in data.columns if 'score' in i]
score_data = data[score_cols]
score_data
# Out:
#       FWBscore  FSscore  LMscore  KHscore
# 0           55       44        3    1.267
# 1           51       43        3   -0.570
# 2           49       42        3   -0.188
# 3           49       42        2   -1.485
# 4           49       42        1   -1.900
# ...        ...      ...      ...      ...
# 6389        61       47        3    1.267
# 6390        59       59        1   -1.215
# 6391        59       51        2   -1.215
# 6392        46       54        2   -1.215
# 6393        49       42        2   -1.215
#
# [6394 rows x 4 columns]

# %% [markdown]
# Standardize the features in your dataset using scikit-learn's StandardScaler, which will set the mean of each feature to 0 and the variance to 1.

# %%
scaler = StandardScaler()
standard_data = scaler.fit_transform(score_data)
standard_data
# Out:
# array([[-0.07306245, -0.53090616,  0.65383032,  1.62471561],
#        [-0.35567668, -0.6099205 ,  0.65383032, -0.62962645],
#        [-0.4969838 , -0.68893483,  0.65383032, -0.16084111],
#        ...,
#        [ 0.20955178,  0.02219421, -0.67039872, -1.42116191],
#        [-0.70894447,  0.25923722, -0.67039872, -1.42116191],
#        [-0.4969838 , -0.68893483, -0.67039872, -1.42116191]])

# %%
distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
for k in range (2,31):
    k_means = KMeans(n_clusters = k, random_state=123)
    k_means.fit(standard_data)
    
    distortions.append(sum(np.min(cdist(standard_data, k_means.cluster_centers_, 
                      'euclidean'),axis=1)) / standard_data.shape[0]) 
    inertias.append(k_means.inertia_) 
  
    mapping1[k] = sum(np.min(cdist(standard_data, k_means.cluster_centers_, 
                 'euclidean'),axis=1)) / standard_data.shape[0] 
    mapping2[k] = k_means.inertia_

# %% [markdown]
# Create an elbow plot showing how the SSE changes with respect to the number of clusters in K-Means. Allow K to vary from 2 to 30. Does a clear "elbow" emerge from the plot?

# %%
len(inertias)
# Out:
# 29

# %%
K = range(2,31)
plt.plot(K, intertias, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-b0f4f46333d2> in <module>
#       1 K = range(2,31)
# ----> 2 plt.plot(K, intertias, 'bx-')
#       3 plt.xlabel('Values of K')
#       4 plt.ylabel('Distortion')
#       5 plt.title('The Elbow Method using Distortion')
#
# /opt/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# /opt/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# /opt/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# /opt/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# /opt/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (29,) and (0,)

# %%
bws = estimate_bandwidth(standard_data)
bws
# Out:
# 1.9962824784211841

# %% [markdown]
# Create a silhouette plot for the results of K-Means, again with K varying from 2 to 30. What is the optimal number of clusters according to the silhouette method? Is this consistent with the output of the elbow plot?

# %%
sscores = []
dscores = []
bws = np.arange(0.1, 1.1, 0.1)
for bw in bws:
    clst = KMeans(bw)
    clst.fit(standard_data)

    sscore = silhouette_score(standard_data, clst.labels_)
    dscore = davies_bouldin_score(standard_data, clst.labels_)

    sscores.append(sscore)
    dscores.append(dscore)

    print("\n---------------------------------------------\n")
    
plt.plot(bws, sscores, ls='-.')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-54870d884571> in <module>
#       4 for bw in bws:
#       5     clst = KMeans(bw)
# ----> 6     clst.fit(standard_data)
#       7
#       8     sscore = silhouette_score(standard_data, clst.labels_)
#
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     935                     max_iter=self.max_iter, init=init, verbose=self.verbose,
#     936                     precompute_distances=precompute_distances, tol=tol,
# --> 937                     x_squared_norms=x_squared_norms, random_state=seed)
#     938                 # determine if these results are the best so far
#     939                 if best_inertia is None or inertia < best_inertia:
#
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     312     # init
#     313     centers = _init_centroids(X, n_clusters, init, random_state=random_state,
# --> 314                               x_squared_norms=x_squared_norms)
#     315     centers = np.ascontiguousarray(centers)
#     316     if verbose:
#
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in _init_centroids(X, k, init, random_state, x_squared_norms, init_size)
#     624     if isinstance(init, str) and init == 'k-means++':
#     625         centers = _k_init(X, k, random_state=random_state,
# --> 626                           x_squared_norms=x_squared_norms)
#     627     elif isinstance(init, str) and init == 'random':
#     628         seeds = random_state.permutation(n_samples)[:k]
#
# /opt/miniconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py in _k_init(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#      77     n_samples, n_features = X.shape
#      78
# ---> 79     centers = np.empty((n_clusters, n_features), dtype=X.dtype)
#      80
#      81     assert x_squared_norms is not None, 'x_squared_norms None in _k_init'
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer

# %%
# answer goes here
